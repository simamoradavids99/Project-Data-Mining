# %%
# Importing required libraries.
import pandas as pd
import numpy as np
import seaborn as sns #visualisation
import matplotlib.pyplot as plt #visualisation
# %matplotlib inline 
sns.set(color_codes=True)

# %%
df = pd.read_csv('C:/Users/David/Program/PRaktikum-DAMI/proejct/hepatitis.csv')

# %%
df.head(5)
# Out:
#    class  age  sex  steroid  antivirals  fatigue  malaise  anorexia  \
# 0      2   30    2        1           2        2        2         2
# 1      2   50    1        1           2        1        2         2
# 2      2   78    1        2           2        1        2         2
# 3      2   34    1        2           2        2        2         2
# 4      2   34    1        2           2        2        2         2
#
#    liver_big  liver_firm  spleen_palable  spiders  ascites  varices  \
# 0          1           2               2        2        2        2
# 1          1           2               2        2        2        2
# 2          2           2               2        2        2        2
# 3          2           2               2        2        2        2
# 4          2           2               2        2        2        2
#
#    bilirubin  alk_phosphate  sgot  albumin  protime  histology
# 0        1.0             85    18      4.0       61          1
# 1        0.9            135    42      3.5       61          1
# 2        0.7             96    32      4.0       61          1
# 3        1.0            105   200      4.0       61          1
# 4        0.9             95    28      4.0       75          1

# %%
df.tail(5)
# Out:
#      class  age  sex  steroid  antivirals  fatigue  malaise  anorexia  \
# 137      1   46    1        2           2        1        1         1
# 138      2   44    1        2           2        1        2         2
# 139      2   61    1        1           2        1        1         2
# 140      2   53    2        1           2        1        2         2
# 141      1   43    1        2           2        1        2         2
#
#      liver_big  liver_firm  spleen_palable  spiders  ascites  varices  \
# 137          2           1               2        1        1        1
# 138          2           1               2        2        2        2
# 139          1           2               2        1        2        2
# 140          2           2               1        1        2        1
# 141          2           2               1        1        1        2
#
#      bilirubin  alk_phosphate  sgot  albumin  protime  histology
# 137        7.6            105   242      3.3       50          2
# 138        0.9            126   142      4.3       61          2
# 139        0.8             75    20      4.1       61          2
# 140        1.5             81    19      4.1       48          2
# 141        1.2            100    19      3.1       42          2

# %%
df.columns
# Out:
# Index(['class', 'age', 'sex', 'steroid', 'antivirals', 'fatigue', 'malaise',
#        'anorexia', 'liver_big', 'liver_firm', 'spleen_palable', 'spiders',
#        'ascites', 'varices', 'bilirubin', 'alk_phosphate', 'sgot', 'albumin',
#        'protime', 'histology'],
#       dtype='object')

# %%
#checking the type of data
df.dtypes
# Out:
# class               int64
# age                 int64
# sex                 int64
# steroid             int64
# antivirals          int64
# fatigue             int64
# malaise             int64
# anorexia            int64
# liver_big           int64
# liver_firm          int64
# spleen_palable      int64
# spiders             int64
# ascites             int64
# varices             int64
# bilirubin         float64
# alk_phosphate       int64
# sgot                int64
# albumin           float64
# protime             int64
# histology           int64
# dtype: object

# %%
df.shape
# Out:
# (142, 20)

# %%
df.describe()
# Out:
#             class         age         sex     steroid  antivirals     fatigue  \
# count  142.000000  142.000000  142.000000  142.000000  142.000000  142.000000
# mean     1.816901   40.816901    1.105634    1.514085    1.838028    1.359155
# std      0.388116   12.189182    0.308456    0.501571    0.369729    0.481451
# min      1.000000    7.000000    1.000000    1.000000    1.000000    1.000000
# 25%      2.000000   32.000000    1.000000    1.000000    2.000000    1.000000
# 50%      2.000000   39.000000    1.000000    2.000000    2.000000    1.000000
# 75%      2.000000   50.000000    1.000000    2.000000    2.000000    2.000000
# max      2.000000   78.000000    2.000000    2.000000    2.000000    2.000000
#
#           malaise    anorexia   liver_big  liver_firm  spleen_palable  \
# count  142.000000  142.000000  142.000000  142.000000      142.000000
# mean     1.619718    1.795775    1.823944    1.584507        1.809859
# std      0.487174    0.404561    0.382216    0.494551        0.393801
# min      1.000000    1.000000    1.000000    1.000000        1.000000
# 25%      1.000000    2.000000    2.000000    1.000000        2.000000
# 50%      2.000000    2.000000    2.000000    2.000000        2.000000
# 75%      2.000000    2.000000    2.000000    2.000000        2.000000
# max      2.000000    2.000000    2.000000    2.000000        2.000000
#
#           spiders     ascites     varices   bilirubin  alk_phosphate  \
# count  142.000000  142.000000  142.000000  142.000000     142.000000
# mean     1.669014    1.880282    1.880282    1.382958     105.647887
# std      0.472234    0.325781    0.325781    1.166526      47.375099
# min      1.000000    1.000000    1.000000    0.300000      26.000000
# 25%      1.000000    2.000000    2.000000    0.700000      78.500000
# 50%      2.000000    2.000000    2.000000    1.000000     100.000000
# 75%      2.000000    2.000000    2.000000    1.480000     119.750000
# max      2.000000    2.000000    2.000000    8.000000     295.000000
#
#              sgot     albumin     protime   histology
# count  142.000000  142.000000  142.000000  142.000000
# mean    83.507042    3.830493   61.704225    1.443662
# std     82.417700    0.618103   17.696732    0.498575
# min     14.000000    2.100000    0.000000    1.000000
# 25%     32.250000    3.500000   56.250000    1.000000
# 50%     58.000000    3.900000   61.000000    1.000000
# 75%     99.500000    4.200000   66.000000    2.000000
# max    648.000000    6.400000  100.000000    2.000000

# %%
#missing data
total = df.isnull().sum().sort_values(ascending=False)
percent = (df.isnull().sum()/df.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data.head(20)
# Out:
#                 Total  Percent
# histology           0      0.0
# protime             0      0.0
# age                 0      0.0
# sex                 0      0.0
# steroid             0      0.0
# antivirals          0      0.0
# fatigue             0      0.0
# malaise             0      0.0
# anorexia            0      0.0
# liver_big           0      0.0
# liver_firm          0      0.0
# spleen_palable      0      0.0
# spiders             0      0.0
# ascites             0      0.0
# varices             0      0.0
# bilirubin           0      0.0
# alk_phosphate       0      0.0
# sgot                0      0.0
# albumin             0      0.0
# class               0      0.0

# %%
# Rows containing duplicate data
duplicate_rows_df = df[df.duplicated()]
print("number of duplicate rows:", duplicate_rows_df.shape)
# Out:
# number of duplicate rows: (0, 20)

# %%
df = df.drop_duplicates()

# %%
sns.boxplot(x=df['bilirubin'])
# Out:
# <AxesSubplot:xlabel='bilirubin'>

# %%
sns.boxplot(x=df['protime'])
# Out:
# <AxesSubplot:xlabel='protime'>

# %%
sns.boxplot(x=df['age'])
# Out:
# <AxesSubplot:xlabel='age'>

# %%
sns.boxplot(x=df['alk_phosphate'])
# Out:
# <AxesSubplot:xlabel='alk_phosphate'>

# %%
sns.boxplot(x=df['sgot'])
# Out:
# <AxesSubplot:xlabel='sgot'>

# %%
sns.boxplot(x=df['albumin'])
# Out:
# <AxesSubplot:xlabel='albumin'>

# %%
Q1 = df[['age','bilirubin','alk_phosphate','sgot', 'albumin']].quantile(0.25)
Q3 = df[['age','bilirubin','alk_phosphate','sgot','albumin']].quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# age              18.00
# bilirubin         0.78
# alk_phosphate    41.25
# sgot             67.25
# albumin           0.70
# dtype: float64

# %%
df = df[~((df < (Q1 - 1.5 * IQR)) |(df > (Q3 + 1.5 * IQR))).any(axis=1)]
df.shape
# Out:
# (108, 20)

# %%
# Finding the relations between the variables.
plt.figure(figsize=(20,10))
c= df.corr()
sns.heatmap(c,cmap="BrBG",annot=True)
c
# Out:
#                    class       age       sex   steroid  antivirals   fatigue  \
# class           1.000000 -0.160050  0.162705  0.086206   -0.109289  0.278514
# age            -0.160050  1.000000 -0.028773 -0.022776   -0.044396 -0.243713
# sex             0.162705 -0.028773  1.000000 -0.032605   -0.097661 -0.066254
# steroid         0.086206 -0.022776 -0.032605  1.000000    0.069755  0.140436
# antivirals     -0.109289 -0.044396 -0.097661  0.069755    1.000000 -0.029461
# fatigue         0.278514 -0.243713 -0.066254  0.140436   -0.029461  1.000000
# malaise         0.341807 -0.033306 -0.013959  0.225246    0.009982  0.586435
# anorexia        0.166678  0.120364  0.003602  0.101654   -0.033057  0.379249
# liver_big      -0.075417 -0.112006 -0.081761  0.216497    0.047713  0.114808
# liver_firm      0.081185 -0.088006 -0.082179  0.095238    0.094782  0.273741
# spleen_palable  0.188224 -0.075270 -0.067021  0.067514   -0.164311  0.175707
# spiders         0.402217 -0.197884 -0.050403  0.034793   -0.146747  0.370594
# ascites         0.498499 -0.087715  0.126740 -0.054713   -0.162129  0.276079
# varices         0.386317 -0.055567  0.056163 -0.054713   -0.162129  0.185645
# bilirubin      -0.461533  0.147050 -0.050150 -0.065891    0.169175 -0.299168
# alk_phosphate  -0.149718 -0.030141  0.039448 -0.002476    0.186619 -0.130298
# sgot           -0.025457 -0.013709 -0.005748 -0.026080    0.103492 -0.187825
# albumin         0.454181 -0.216044  0.032088  0.178985   -0.161645  0.293016
# protime         0.298737 -0.127427 -0.011126  0.063595   -0.010626  0.194021
# histology      -0.310245  0.181512 -0.122436 -0.096067    0.200227 -0.136702
#
#                  malaise  anorexia  liver_big  liver_firm  spleen_palable  \
# class           0.341807  0.166678  -0.075417    0.081185        0.188224
# age            -0.033306  0.120364  -0.112006   -0.088006       -0.075270
# sex            -0.013959  0.003602  -0.081761   -0.082179       -0.067021
# steroid         0.225246  0.101654   0.216497    0.095238        0.067514
# antivirals      0.009982 -0.033057   0.047713    0.094782       -0.164311
# fatigue         0.586435  0.379249   0.114808    0.273741        0.175707
# malaise         1.000000  0.610718   0.056864    0.134330        0.027075
# anorexia        0.610718  1.000000   0.086886    0.104595        0.066147
# liver_big       0.056864  0.086886   1.000000    0.435705        0.105851
# liver_firm      0.134330  0.104595   0.435705    1.000000        0.137714
# spleen_palable  0.027075  0.066147   0.105851    0.137714        1.000000
# spiders         0.343011  0.311883   0.224966    0.318006        0.269376
# ascites         0.336718  0.189854  -0.113513    0.085249        0.042434
# varices         0.202660  0.189854  -0.056556    0.173288        0.208278
# bilirubin      -0.342195 -0.362389  -0.008686   -0.126936       -0.160564
# alk_phosphate  -0.184377 -0.169926  -0.124866   -0.348345       -0.270479
# sgot           -0.180630 -0.171502   0.043604   -0.191415       -0.004001
# albumin         0.301391  0.174548  -0.049763    0.187444        0.191526
# protime         0.183469  0.029146  -0.066471    0.049877        0.108906
# histology      -0.147228 -0.075028  -0.071027   -0.167516       -0.181374
#
#                  spiders   ascites   varices  bilirubin  alk_phosphate  \
# class           0.402217  0.498499  0.386317  -0.461533      -0.149718
# age            -0.197884 -0.087715 -0.055567   0.147050      -0.030141
# sex            -0.050403  0.126740  0.056163  -0.050150       0.039448
# steroid         0.034793 -0.054713 -0.054713  -0.065891      -0.002476
# antivirals     -0.146747 -0.162129 -0.162129   0.169175       0.186619
# fatigue         0.370594  0.276079  0.185645  -0.299168      -0.130298
# malaise         0.343011  0.336718  0.202660  -0.342195      -0.184377
# anorexia        0.311883  0.189854  0.189854  -0.362389      -0.169926
# liver_big       0.224966 -0.113513 -0.056556  -0.008686      -0.124866
# liver_firm      0.318006  0.085249  0.173288  -0.126936      -0.348345
# spleen_palable  0.269376  0.042434  0.208278  -0.160564      -0.270479
# spiders         1.000000  0.293804  0.386004  -0.290203      -0.278509
# ascites         0.293804  1.000000  0.398588  -0.305867      -0.117171
# varices         0.386004  0.398588  1.000000  -0.387980      -0.306953
# bilirubin      -0.290203 -0.305867 -0.387980   1.000000       0.193034
# alk_phosphate  -0.278509 -0.117171 -0.306953   0.193034       1.000000
# sgot           -0.122667 -0.008817 -0.015949   0.289753       0.227686
# albumin         0.296507  0.553608  0.352499  -0.406031      -0.321027
# protime         0.238556  0.287823  0.250918  -0.216918      -0.185960
# histology      -0.335804 -0.325636 -0.369300   0.263319       0.263085
#
#                     sgot   albumin   protime  histology
# class          -0.025457  0.454181  0.298737  -0.310245
# age            -0.013709 -0.216044 -0.127427   0.181512
# sex            -0.005748  0.032088 -0.011126  -0.122436
# steroid        -0.026080  0.178985  0.063595  -0.096067
# antivirals      0.103492 -0.161645 -0.010626   0.200227
# fatigue        -0.187825  0.293016  0.194021  -0.136702
# malaise        -0.180630  0.301391  0.183469  -0.147228
# anorexia       -0.171502  0.174548  0.029146  -0.075028
# liver_big       0.043604 -0.049763 -0.066471  -0.071027
# liver_firm     -0.191415  0.187444  0.049877  -0.167516
# spleen_palable -0.004001  0.191526  0.108906  -0.181374
# spiders        -0.122667  0.296507  0.238556  -0.335804
# ascites        -0.008817  0.553608  0.287823  -0.325636
# varices        -0.015949  0.352499  0.250918  -0.369300
# bilirubin       0.289753 -0.406031 -0.216918   0.263319
# alk_phosphate   0.227686 -0.321027 -0.185960   0.263085
# sgot            1.000000 -0.083968 -0.101656   0.126522
# albumin        -0.083968  1.000000  0.294590  -0.295983
# protime        -0.101656  0.294590  1.000000  -0.222952
# histology       0.126522 -0.295983 -0.222952   1.000000

# %%
fig, ax = plt.subplots(figsize=(10,6))
ax.scatter(df['age'], df['histology'])
ax.set_xlabel('age')
ax.set_ylabel('histology')
plt.show()
